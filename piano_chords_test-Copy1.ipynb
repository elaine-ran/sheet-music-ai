# %% [markdown]
# dataset from CHLOE ZHAO again!!!

# %%
import os
import numpy as np
import pandas as pd
import librosa
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MultiLabelBinarizer, StandardScaler
from keras.utils import to_categorical
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten, Conv1D, MaxPooling1D, Input
import seaborn as sns
import matplotlib.pyplot as plt

# %%
notchloe = True

# %%
def not_chloe(b):
    if b is True:
        return "elaineran", "Desktop"
    else: 
        return "chloezhao", "summer 2024 project"

# %%
data_path = "/Users/"+not_chloe(notchloe)[0] + "/"+not_chloe(notchloe)[1]+"/summer-project/generated_chords/"
metadata_path = "/Users/"+not_chloe(notchloe)[0] +"/"+not_chloe(notchloe)[1]+"/summer-project/piano_chords.csv"

# %%
def load_data(data_path, metadata_path):
    features = []
    labels = []


    metadata = pd.read_csv(metadata_path)


    for index, row in metadata.iterrows():
        file_path = os.path.join(data_path, f"{row['File Names']}.wav")


        # Load the audio file and resample it
        target_sr = 22050
        audio, sample_rate = librosa.load(file_path, sr=target_sr)

        # Check if the audio length is less than the default n_fft size
        if len(audio) < 2048:
            # Pad the audio file with zeros
            audio = np.pad(audio, (0, 2048 - len(audio)), mode='constant')



        # Extract MFCC features
        mfccs = librosa.feature.mfcc(y=audio, sr=target_sr, n_mfcc=40)
        mfccs_scaled = np.mean(mfccs.T, axis=0)


        # Append features and labels
        features.append(mfccs_scaled)
        labels.append(row['Number of Notes'])


    return np.array(features), np.array(labels)

# %%
features, labels = load_data(data_path, metadata_path)


# Encode labels
le = LabelEncoder()
labels_encoded = le.fit_transform(labels)
labels_onehot = to_categorical(labels_encoded)

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, labels_onehot, test_size=0.2, random_state=42)

# %%
input_shape = (X_train.shape[1], 1)
model = Sequential()
model.add(Conv1D(64, 3, padding='same', activation='relu', input_shape=input_shape))
model.add(MaxPooling1D(pool_size=2))
model.add(Dropout(0.25))
model.add(Conv1D(128, 3, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(le.classes_), activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
history = model.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 2024-06-30 18:17:25.419539: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-06-30 18:17:25.484155: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node AssignAddVariableOp_10.
# 23/25 [==========================>...] - ETA: 0s - loss: 14.3525 - accuracy: 0.1780
# 2024-06-30 18:17:26.425449: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 25/25 [==============================] - 3s 68ms/step - loss: 13.8079 - accuracy: 0.1800 - val_loss: 3.7084 - val_accuracy: 0.2250
# Epoch 2/100
# 25/25 [==============================] - 1s 21ms/step - loss: 5.8850 - accuracy: 0.2512 - val_loss: 2.6326 - val_accuracy: 0.2650
# Epoch 3/100
# 25/25 [==============================] - 1s 21ms/step - loss: 3.2560 - accuracy: 0.2600 - val_loss: 1.8279 - val_accuracy: 0.2650
# Epoch 4/100
# 25/25 [==============================] - 1s 21ms/step - loss: 2.5868 - accuracy: 0.2800 - val_loss: 1.8448 - val_accuracy: 0.2850
# Epoch 5/100
# 25/25 [==============================] - 1s 20ms/step - loss: 2.2533 - accuracy: 0.2825 - val_loss: 1.7998 - val_accuracy: 0.2950
# Epoch 6/100
# 25/25 [==============================] - 1s 20ms/step - loss: 2.2328 - accuracy: 0.3013 - val_loss: 1.9971 - val_accuracy: 0.3000
# Epoch 7/100
# 25/25 [==============================] - 1s 20ms/step - loss: 1.9999 - accuracy: 0.3000 - val_loss: 1.9048 - val_accuracy: 0.2900
# Epoch 8/100
# 25/25 [==============================] - 0s 20ms/step - loss: 1.9287 - accuracy: 0.3212 - val_loss: 1.6907 - val_accuracy: 0.3000
# Epoch 9/100
# 25/25 [==============================] - 0s 20ms/step - loss: 1.9585 - accuracy: 0.3113 - val_loss: 1.7421 - val_accuracy: 0.2900
# Epoch 10/100
# 25/25 [==============================] - 1s 20ms/step - loss: 1.7695 - accuracy: 0.3400 - val_loss: 1.6890 - val_accuracy: 0.2850
# Epoch 11/100
# 25/25 [==============================] - 1s 20ms/step - loss: 1.7264 - accuracy: 0.3487 - val_loss: 1.7856 - val_accuracy: 0.2950
# Epoch 12/100
# 25/25 [==============================] - 1s 21ms/step - loss: 1.8586 - accuracy: 0.3300 - val_loss: 1.6279 - val_accuracy: 0.2850
# Epoch 13/100
# 25/25 [==============================] - 1s 20ms/step - loss: 1.7056 - accuracy: 0.3487 - val_loss: 1.6828 - val_accuracy: 0.3050
# Epoch 14/100
# 25/25 [==============================] - 1s 20ms/step - loss: 1.6754 - accuracy: 0.3837 - val_loss: 1.7010 - val_accuracy: 0.3050
# Epoch 15/100
# 25/25 [==============================] - 1s 20ms/step - loss: 1.6793 - accuracy: 0.3688 - val_loss: 1.6218 - val_accuracy: 0.2950
# Epoch 16/100
# 25/25 [==============================] - 1s 20ms/step - loss: 1.5472 - accuracy: 0.4175 - val_loss: 1.6644 - val_accuracy: 0.3200
# Epoch 17/100
# 25/25 [==============================] - 1s 20ms/step - loss: 1.5986 - accuracy: 0.3950 - val_loss: 1.7312 - val_accuracy: 0.3350
# Epoch 18/100
# 25/25 [==============================] - 1s 21ms/step - loss: 1.7220 - accuracy: 0.3825 - val_loss: 1.7681 - val_accuracy: 0.3150
# Epoch 19/100
# 25/25 [==============================] - 1s 21ms/step - loss: 1.6685 - accuracy: 0.3938 - val_loss: 1.8715 - val_accuracy: 0.2650
# Epoch 20/100
# 25/25 [==============================] - 1s 21ms/step - loss: 1.6123 - accuracy: 0.4000 - val_loss: 1.7022 - val_accuracy: 0.2900
# Epoch 21/100
# 25/25 [==============================] - 1s 20ms/step - loss: 1.4876 - accuracy: 0.4137 - val_loss: 1.6168 - val_accuracy: 0.3400
# Epoch 22/100
# 25/25 [==============================] - 1s 21ms/step - loss: 1.5442 - accuracy: 0.3950 - val_loss: 1.7711 - val_accuracy: 0.3100
# Epoch 23/100
# 25/25 [==============================] - 1s 20ms/step - loss: 1.4648 - accuracy: 0.4400 - val_loss: 1.7589 - val_accuracy: 0.2900
# Epoch 24/100
# 25/25 [==============================] - 1s 20ms/step - loss: 1.4935 - accuracy: 0.4325 - val_loss: 1.7258 - val_accuracy: 0.3000
# Epoch 25/100
# 25/25 [==============================] - 1s 20ms/step - loss: 1.4388 - accuracy: 0.4475 - val_loss: 1.6823 - val_accuracy: 0.3100
# Epoch 26/100
# 25/25 [==============================] - 1s 20ms/step - loss: 1.4907 - accuracy: 0.4313 - val_loss: 1.7087 - val_accuracy: 0.3100
# Epoch 27/100
# 25/25 [==============================] - 1s 20ms/step - loss: 1.4455 - accuracy: 0.4575 - val_loss: 1.7379 - val_accuracy: 0.3050
# Epoch 28/100
# 25/25 [==============================] - 1s 21ms/step - loss: 1.4389 - accuracy: 0.4625 - val_loss: 1.7641 - val_accuracy: 0.3000
# Epoch 29/100
# 25/25 [==============================] - 1s 20ms/step - loss: 1.4325 - accuracy: 0.4338 - val_loss: 1.5835 - val_accuracy: 0.3550
# Epoch 30/100
# 25/25 [==============================] - 1s 21ms/step - loss: 1.4230 - accuracy: 0.4737 - val_loss: 1.5868 - val_accuracy: 0.3400
# Epoch 31/100
# 25/25 [==============================] - 1s 21ms/step - loss: 1.4187 - accuracy: 0.4688 - val_loss: 1.6687 - val_accuracy: 0.3350
# Epoch 32/100
# 25/25 [==============================] - 1s 20ms/step - loss: 1.3504 - accuracy: 0.4938 - val_loss: 1.7451 - val_accuracy: 0.3200
# Epoch 33/100
# 25/25 [==============================] - 1s 20ms/step - loss: 1.4780 - accuracy: 0.4625 - val_loss: 1.6858 - val_accuracy: 0.3000
# Epoch 34/100
# 25/25 [==============================] - 1s 21ms/step - loss: 1.3044 - accuracy: 0.5038 - val_loss: 1.8180 - val_accuracy: 0.3050
# Epoch 35/100
# 25/25 [==============================] - 1s 21ms/step - loss: 1.3860 - accuracy: 0.5175 - val_loss: 1.8577 - val_accuracy: 0.3000
# Epoch 36/100
# 25/25 [==============================] - 1s 20ms/step - loss: 1.4510 - accuracy: 0.4675 - val_loss: 1.7271 - val_accuracy: 0.3100
# Epoch 37/100
# 25/25 [==============================] - 1s 20ms/step - loss: 1.3394 - accuracy: 0.5113 - val_loss: 1.8667 - val_accuracy: 0.3350
# Epoch 38/100
# 25/25 [==============================] - 1s 20ms/step - loss: 1.3785 - accuracy: 0.4837 - val_loss: 1.9563 - val_accuracy: 0.3050
# Epoch 39/100
# 25/25 [==============================] - 1s 20ms/step - loss: 1.4022 - accuracy: 0.4837 - val_loss: 2.1188 - val_accuracy: 0.3150
# Epoch 40/100
# 25/25 [==============================] - 1s 21ms/step - loss: 1.4131 - accuracy: 0.4863 - val_loss: 1.9081 - val_accuracy: 0.2850
# Epoch 41/100
# 25/25 [==============================] - 1s 20ms/step - loss: 1.4848 - accuracy: 0.5163 - val_loss: 1.9362 - val_accuracy: 0.2900
# Epoch 42/100
# 25/25 [==============================] - 1s 20ms/step - loss: 1.4206 - accuracy: 0.5350 - val_loss: 1.9372 - val_accuracy: 0.2800
# Epoch 43/100
# 25/25 [==============================] - 1s 20ms/step - loss: 1.4773 - accuracy: 0.5238 - val_loss: 1.9694 - val_accuracy: 0.3350
# Epoch 44/100
# 25/25 [==============================] - 1s 20ms/step - loss: 1.4264 - accuracy: 0.5213 - val_loss: 1.8641 - val_accuracy: 0.3050
# Epoch 45/100
# 25/25 [==============================] - 1s 20ms/step - loss: 1.3900 - accuracy: 0.5150 - val_loss: 2.0422 - val_accuracy: 0.2800
# Epoch 46/100
# 25/25 [==============================] - 1s 21ms/step - loss: 1.4407 - accuracy: 0.5238 - val_loss: 2.0439 - val_accuracy: 0.2750
# Epoch 47/100
# 25/25 [==============================] - 1s 21ms/step - loss: 1.4892 - accuracy: 0.5325 - val_loss: 2.3592 - val_accuracy: 0.3300
# Epoch 48/100
# 25/25 [==============================] - 1s 21ms/step - loss: 1.5804 - accuracy: 0.5500 - val_loss: 2.2208 - val_accuracy: 0.2950
# Epoch 49/100
# 25/25 [==============================] - 1s 23ms/step - loss: 1.5738 - accuracy: 0.5325 - val_loss: 2.2800 - val_accuracy: 0.3000
# Epoch 50/100
# 25/25 [==============================] - 1s 20ms/step - loss: 1.6468 - accuracy: 0.5337 - val_loss: 2.3738 - val_accuracy: 0.3100
# Epoch 51/100
# 25/25 [==============================] - 1s 21ms/step - loss: 1.8432 - accuracy: 0.5113 - val_loss: 2.6991 - val_accuracy: 0.3200
# Epoch 52/100
# 25/25 [==============================] - 1s 21ms/step - loss: 1.8470 - accuracy: 0.4988 - val_loss: 3.2065 - val_accuracy: 0.2750
# Epoch 53/100
# 25/25 [==============================] - 1s 24ms/step - loss: 1.8489 - accuracy: 0.4900 - val_loss: 2.6997 - val_accuracy: 0.3400
# Epoch 54/100
# 25/25 [==============================] - 1s 22ms/step - loss: 1.8157 - accuracy: 0.5325 - val_loss: 2.7061 - val_accuracy: 0.2950
# Epoch 55/100
# 25/25 [==============================] - 1s 22ms/step - loss: 1.9590 - accuracy: 0.5238 - val_loss: 3.0565 - val_accuracy: 0.2850
# Epoch 56/100
# 25/25 [==============================] - 1s 22ms/step - loss: 1.9435 - accuracy: 0.5350 - val_loss: 3.6579 - val_accuracy: 0.3150
# Epoch 57/100
# 25/25 [==============================] - 1s 22ms/step - loss: 2.3597 - accuracy: 0.5337 - val_loss: 4.2322 - val_accuracy: 0.3100
# Epoch 58/100
# 25/25 [==============================] - 1s 21ms/step - loss: 2.5690 - accuracy: 0.5200 - val_loss: 3.4631 - val_accuracy: 0.2800
# Epoch 59/100
# 25/25 [==============================] - 1s 22ms/step - loss: 2.1773 - accuracy: 0.5325 - val_loss: 3.3625 - val_accuracy: 0.3100
# Epoch 60/100
# 25/25 [==============================] - 1s 21ms/step - loss: 2.2183 - accuracy: 0.5425 - val_loss: 4.0664 - val_accuracy: 0.2950
# Epoch 61/100
# 25/25 [==============================] - 1s 20ms/step - loss: 2.6716 - accuracy: 0.5100 - val_loss: 4.0789 - val_accuracy: 0.3100
# Epoch 62/100
# 25/25 [==============================] - 1s 21ms/step - loss: 2.9577 - accuracy: 0.5250 - val_loss: 4.7061 - val_accuracy: 0.3200
# Epoch 63/100
# 25/25 [==============================] - 1s 21ms/step - loss: 3.1973 - accuracy: 0.5175 - val_loss: 5.7403 - val_accuracy: 0.2400
# Epoch 64/100
# 25/25 [==============================] - 1s 22ms/step - loss: 4.3881 - accuracy: 0.4475 - val_loss: 5.1487 - val_accuracy: 0.3200
# Epoch 65/100
# 25/25 [==============================] - 1s 23ms/step - loss: 4.2757 - accuracy: 0.4850 - val_loss: 6.1118 - val_accuracy: 0.2400
# Epoch 66/100
# 25/25 [==============================] - 1s 21ms/step - loss: 4.4806 - accuracy: 0.4675 - val_loss: 6.9767 - val_accuracy: 0.2600
# Epoch 67/100
# 25/25 [==============================] - 0s 20ms/step - loss: 4.3709 - accuracy: 0.4925 - val_loss: 6.0284 - val_accuracy: 0.3100
# Epoch 68/100
# 25/25 [==============================] - 1s 20ms/step - loss: 5.0853 - accuracy: 0.4750 - val_loss: 5.9031 - val_accuracy: 0.2850
# Epoch 69/100
# 25/25 [==============================] - 0s 20ms/step - loss: 4.7623 - accuracy: 0.5125 - val_loss: 8.0905 - val_accuracy: 0.3200
# Epoch 70/100
# 25/25 [==============================] - 1s 20ms/step - loss: 5.3622 - accuracy: 0.5100 - val_loss: 7.1887 - val_accuracy: 0.2900
# Epoch 71/100
# 25/25 [==============================] - 0s 20ms/step - loss: 6.0666 - accuracy: 0.4812 - val_loss: 8.4720 - val_accuracy: 0.2850
# Epoch 72/100
# 25/25 [==============================] - 0s 20ms/step - loss: 6.5595 - accuracy: 0.4663 - val_loss: 8.0877 - val_accuracy: 0.3150
# Epoch 73/100
# 25/25 [==============================] - 0s 20ms/step - loss: 5.9821 - accuracy: 0.5175 - val_loss: 7.8211 - val_accuracy: 0.3300
# Epoch 74/100
# 25/25 [==============================] - 0s 20ms/step - loss: 6.5346 - accuracy: 0.4875 - val_loss: 10.6104 - val_accuracy: 0.3350
# Epoch 75/100
# 25/25 [==============================] - 1s 20ms/step - loss: 8.3941 - accuracy: 0.4762 - val_loss: 11.4866 - val_accuracy: 0.3050
# Epoch 76/100
# 25/25 [==============================] - 1s 21ms/step - loss: 10.9026 - accuracy: 0.4712 - val_loss: 11.6813 - val_accuracy: 0.3100
# Epoch 77/100
# 25/25 [==============================] - 1s 21ms/step - loss: 9.5435 - accuracy: 0.4600 - val_loss: 10.7839 - val_accuracy: 0.3300
# Epoch 78/100
# 25/25 [==============================] - 1s 20ms/step - loss: 11.7322 - accuracy: 0.4638 - val_loss: 14.7402 - val_accuracy: 0.3200
# Epoch 79/100
# 25/25 [==============================] - 0s 20ms/step - loss: 10.2388 - accuracy: 0.4888 - val_loss: 13.0908 - val_accuracy: 0.3100
# Epoch 80/100
# 25/25 [==============================] - 1s 20ms/step - loss: 11.4369 - accuracy: 0.4863 - val_loss: 16.3629 - val_accuracy: 0.3300
# Epoch 81/100
# 25/25 [==============================] - 0s 20ms/step - loss: 12.3156 - accuracy: 0.4888 - val_loss: 16.9957 - val_accuracy: 0.3350
# Epoch 82/100
# 25/25 [==============================] - 1s 20ms/step - loss: 13.7532 - accuracy: 0.4975 - val_loss: 17.8958 - val_accuracy: 0.3000
# Epoch 83/100
# 25/25 [==============================] - 1s 20ms/step - loss: 14.6013 - accuracy: 0.5000 - val_loss: 29.2063 - val_accuracy: 0.2850
# Epoch 84/100
# 25/25 [==============================] - 1s 22ms/step - loss: 16.6727 - accuracy: 0.5013 - val_loss: 24.8054 - val_accuracy: 0.3150
# Epoch 85/100
# 25/25 [==============================] - 1s 20ms/step - loss: 18.0809 - accuracy: 0.4638 - val_loss: 22.0122 - val_accuracy: 0.3350
# Epoch 86/100
# 25/25 [==============================] - 1s 20ms/step - loss: 17.6008 - accuracy: 0.5025 - val_loss: 21.7368 - val_accuracy: 0.3250
# Epoch 87/100
# 25/25 [==============================] - 1s 21ms/step - loss: 20.1447 - accuracy: 0.4888 - val_loss: 30.8971 - val_accuracy: 0.3050
# Epoch 88/100
# 25/25 [==============================] - 0s 20ms/step - loss: 21.1454 - accuracy: 0.4837 - val_loss: 30.8347 - val_accuracy: 0.2950
# Epoch 89/100
# 25/25 [==============================] - 0s 20ms/step - loss: 18.8587 - accuracy: 0.5075 - val_loss: 26.4797 - val_accuracy: 0.3250
# Epoch 90/100
# 25/25 [==============================] - 1s 20ms/step - loss: 21.1913 - accuracy: 0.5213 - val_loss: 34.7485 - val_accuracy: 0.2950
# Epoch 91/100
# 25/25 [==============================] - 1s 20ms/step - loss: 24.5160 - accuracy: 0.5100 - val_loss: 34.2581 - val_accuracy: 0.3500
# Epoch 92/100
# 25/25 [==============================] - 1s 20ms/step - loss: 27.2232 - accuracy: 0.4850 - val_loss: 36.5629 - val_accuracy: 0.3200
# Epoch 93/100
# 25/25 [==============================] - 1s 20ms/step - loss: 26.0892 - accuracy: 0.5025 - val_loss: 34.0200 - val_accuracy: 0.3100
# Epoch 94/100
# 25/25 [==============================] - 1s 21ms/step - loss: 32.7683 - accuracy: 0.5150 - val_loss: 53.1868 - val_accuracy: 0.3400
# Epoch 95/100
# 25/25 [==============================] - 1s 21ms/step - loss: 35.2924 - accuracy: 0.4938 - val_loss: 52.4230 - val_accuracy: 0.3100
# Epoch 96/100
# 25/25 [==============================] - 1s 21ms/step - loss: 36.3503 - accuracy: 0.4837 - val_loss: 44.8021 - val_accuracy: 0.3450
# Epoch 97/100
# 25/25 [==============================] - 1s 23ms/step - loss: 47.1847 - accuracy: 0.4575 - val_loss: 50.4941 - val_accuracy: 0.3850
# Epoch 98/100
# 25/25 [==============================] - 1s 23ms/step - loss: 52.3240 - accuracy: 0.4450 - val_loss: 65.7661 - val_accuracy: 0.3300
# Epoch 99/100
# 25/25 [==============================] - 1s 21ms/step - loss: 43.5375 - accuracy: 0.5013 - val_loss: 58.3343 - val_accuracy: 0.3400
# Epoch 100/100
# 25/25 [==============================] - 1s 21ms/step - loss: 45.8926 - accuracy: 0.4975 - val_loss: 77.1029 - val_accuracy: 0.3050

# %%
# plotting from history

loss = history.history['loss']
val_loss = history.history['val_loss']
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

epochs = list(range(len(loss)))

figsize = (6, 4)
fig, axis1 = plt.subplots(figsize=figsize)
plot1_lacc = axis1.plot(epochs, acc, 'navy', label='accuracy')
plot1_val_lacc = axis1.plot(epochs, val_acc, 'deepskyblue', label="validation accuracy")

plot1_loss = axis1.plot(epochs, loss, 'red', label='loss')
plot1_val_loss = axis1.plot(epochs, val_loss, 'lightsalmon', label="validation loss")


plots = plot1_loss + plot1_val_loss
labs = [plot.get_label() for plot in plots]
axis1.set_xlabel('Epoch')
axis1.set_ylabel('Loss/Accuracy')
plt.title("Loss/Accuracy History")
plt.tight_layout()
axis1.legend(loc='lower right')
plt.savefig("/Users/elaineran/Desktop/summer-project/figures/Loss-Accuracy-Notes")
plt.show()

# %%
# plotting from history

loss = history.history['loss']
val_loss = history.history['val_loss']
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

epochs = list(range(len(loss)))

figsize = (6, 4)
fig, axis1 = plt.subplots(figsize=figsize)
plot1_lacc = axis1.plot(epochs, acc, 'navy', label='accuracy')
plot1_val_lacc = axis1.plot(epochs, val_acc, 'deepskyblue', label="validation accuracy")

plot1_loss = axis1.plot(epochs, loss, 'red', label='loss')
plot1_val_loss = axis1.plot(epochs, val_loss, 'lightsalmon', label="validation loss")


plots = plot1_loss + plot1_val_loss
labs = [plot.get_label() for plot in plots]
axis1.set_xlabel('Epoch')
axis1.set_ylabel('Loss/Accuracy')
plt.title("Loss/Accuracy History")
plt.tight_layout()
axis1.legend(loc='lower right')
plt.savefig("/Users/elaineran/Desktop/summer-project/figures/Loss-Accuracy-Notes")
plt.show()

# %%
test_predictions = model.predict(X_test)
# Out:
# 7/7 [==============================] - 0s 5ms/step

# %%
predicted_class_indices = np.argmax(test_predictions, axis=1)
predicted_classes = le.inverse_transform(predicted_class_indices)
print(predicted_classes)
# Out:
# [8 3 5 3 6 8 4 4 8 8 3 8 6 3 5 2 8 5 6 8 8 8 6 5 5 5 5 2 3 8 3 5 5 8 6 8 3
#  3 4 8 3 8 8 3 8 3 6 2 2 6 3 8 6 2 2 4 2 4 8 2 8 3 3 2 4 3 8 8 5 3 2 3 6 4
#  3 2 2 4 8 4 8 3 8 8 8 8 3 3 6 8 8 7 8 5 4 3 3 8 4 8 3 3 4 5 8 6 6 6 5 3 4
#  3 4 3 3 5 6 8 3 3 2 6 5 5 5 5 4 3 6 8 6 6 2 2 5 3 2 8 6 4 4 6 6 8 5 4 5 3
#  8 3 8 3 4 4 6 8 8 3 8 6 3 3 6 8 6 3 8 3 4 3 3 2 8 8 5 8 5 4 4 6 6 6 3 6 8
#  2 2 8 3 8 5 5 8 6 3 6 4 3 5 8]

# %%
y_true = np.argmax(y_test, axis=1)
true_classes = le.inverse_transform(y_true)
print(true_classes)
# Out:
# [8 2 5 4 6 7 3 3 3 8 3 6 4 3 6 2 6 5 4 8 4 6 6 5 6 4 3 2 5 8 2 5 7 7 5 7 2
#  6 4 7 2 7 5 3 8 2 6 2 2 5 6 7 7 2 2 5 2 6 6 2 4 3 2 2 3 5 6 8 8 3 2 2 6 7
#  3 3 3 3 7 4 7 3 8 5 5 6 5 7 3 7 6 7 6 6 6 2 2 5 3 5 2 2 7 3 7 8 6 4 6 5 4
#  2 3 2 2 8 7 7 5 7 2 4 7 6 7 7 3 3 7 7 4 5 2 2 4 4 3 6 4 3 4 8 5 7 4 6 8 3
#  8 3 7 5 4 8 6 7 8 5 6 7 3 4 6 7 5 5 8 8 5 2 3 2 7 8 8 7 7 5 7 4 5 5 4 4 5
#  2 3 6 6 8 4 5 5 5 3 6 6 7 5 8]

# %%
unique_labels = np.unique(np.concatenate([y_true, predicted_class_indices]))


# Calculate accuracy
accuracy = accuracy_score(y_true, predicted_class_indices)
print("Accuracy:", accuracy)


# Generate a classification report
print(classification_report(y_true, predicted_class_indices, labels=unique_labels, target_names=le.inverse_transform(unique_labels)))


# Confusion matrix
cm = confusion_matrix(y_true, predicted_class_indices)
print("Confusion Matrix:\n", cm)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 5
#       1 unique_labels = np.unique(np.concatenate([y_true, predicted_class_indices]))
#       4 # Calculate accuracy
# ----> 5 accuracy = accuracy_score(y_true, predicted_class_indices)
#       6 print("Accuracy:", accuracy)
#       9 # Generate a classification report
#
# NameError: name 'accuracy_score' is not defined

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=le.classes_, yticklabels=le.classes_)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.savefig("/Users/elaineran/Desktop/summer-project/figures/Confusion-Matrix-Notes")
plt.show()

# %%
import soundfile as sf
from pydub import AudioSegment
import librosa.display

# %%
# Load an audio file
audio_path = '/Users/elaineran/Desktop/summer-project/testing_soundfiles/falalala2.wav'
y, sr = librosa.load(audio_path)

# Onset detection
onset_frames = librosa.onset.onset_detect(y=y, sr=sr)
onset_times = librosa.frames_to_time(onset_frames, sr=sr)

# %%
# Plotting the waveform and onsets
plt.figure(figsize=(20, 12))
librosa.display.waveshow(y, sr=sr, alpha=0.6)
plt.vlines(onset_times, ymin=-1, ymax=1, color='r', linestyle='--', label='Onsets')
plt.title('Onset Detection')
plt.legend()
plt.show()

# Print the detected onset times
print('Detected onset times:', onset_times)
# Out:
# Detected onset times: [1.71827664 3.32045351 4.82975057 5.92108844]

# %%
onset_times = np.append(onset_times, librosa.get_duration(y=y, sr=sr))

# Split and save the audio segments
for i in range(len(onset_times) - 1):
    start_sample = int(onset_times[i] * sr)
    end_sample = int(onset_times[i + 1] * sr)
    segment = y[start_sample:end_sample]
    segment_filename = f'segment_{i + 1}.wav'
    sf.write("/Users/elaineran/Desktop/summer-project/testing_soundfiles/" + segment_filename, segment, sr)
    print(f'Saved {segment_filename} from {onset_times[i]:.2f}s to {onset_times[i + 1]:.2f}s')
# Out:
# Saved segment_1.wav from 1.72s to 3.32s
# Saved segment_2.wav from 3.32s to 4.83s
# Saved segment_3.wav from 4.83s to 5.92s
# Saved segment_4.wav from 5.92s to 7.43s

# %%
test_audio_path = "/Users/elaineran/Desktop/summer-project/testing_soundfiles/segment_3.wav"
audio, _ = librosa.load(test_audio_path, sr=22050)
# Pad the audio file if necessary
if len(audio) < 2048:
    audio = np.pad(audio, (0, 2048 - len(audio)), mode='constant')
# Extract MFCC features
mfccs = librosa.feature.mfcc(y=audio, sr=22050, n_mfcc=40)
mfccs_scaled = np.mean(mfccs.T, axis=0)
mfccs_scaled = mfccs_scaled.reshape(1, mfccs_scaled.shape[0], 1)

# Predict the chord
predicted_probabilities = model.predict(mfccs_scaled)
predicted_label = np.argmax(predicted_probabilities, axis=1)
predicted_note = le.inverse_transform(predicted_label)

print(f"The predicted note is: {predicted_note[0]}")
# Out:
# The predicted note is: D

# %%
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import soundfile as sf

# Step 1: Load the audio file
y, sr = librosa.load(y, sr = librosa.load('/Users/elaineran/Downloads/archive2/piano_triads/A_maj_4_0.wav'))

# Step 2: Perform Harmonic-Percussive Source Separation
harmonic, percussive = librosa.effects.hpss(y)

# Step 3: Compute the STFT of the harmonic component
D_harmonic = librosa.stft(harmonic)
S_db_harmonic = librosa.amplitude_to_db(np.abs(D_harmonic), ref=np.max)

# Step 4: Identify Peaks in the Harmonic Spectrogram
# Sum the magnitude of the spectrogram across time
frequency_magnitude = np.mean(np.abs(D_harmonic), axis=1)
# Use a simple peak picking algorithm to identify peaks
peaks, _ = find_peaks(frequency_magnitude, height=np.mean(frequency_magnitude) / 2)

# Step 5: Isolate and Reconstruct Each Note
components = []
for peak in peaks:
    # Create a mask to isolate the peak
    mask = np.zeros_like(D_harmonic, dtype=bool)
    mask[peak-2:peak+3, :] = True  # Isolate the peak and its immediate neighbors
    isolated_D = np.where(mask, D_harmonic, 0)
    isolated_y = librosa.istft(isolated_D)
    components.append(isolated_y)

# Limit to the top 3 most significant peaks
components = components[:3]

# Step 6: Save and/or visualize the isolated components (notes)
for i, component in enumerate(components):
    sf.write(f'isolated_note_{i+1}.wav', component, sr)
    plt.figure(figsize=(10, 4))
    librosa.display.waveshow(component, sr=sr)
    plt.title(f'Isolated Note {i+1}')
    plt.show()

# %%
test_audio_path = "/Users/elaineran/Desktop/summer-project/isolated_note_E.wav"
audio, _ = librosa.load(test_audio_path, sr=22050)
# Pad the audio file if necessary
if len(audio) < 2048:
    audio = np.pad(audio, (0, 2048 - len(audio)), mode='constant')
# Extract MFCC features
mfccs = librosa.feature.mfcc(y=audio, sr=22050, n_mfcc=40)
mfccs_scaled = np.mean(mfccs.T, axis=0)
mfccs_scaled = mfccs_scaled.reshape(1, mfccs_scaled.shape[0], 1)

# Predict the chord
predicted_probabilities = model.predict(mfccs_scaled)
predicted_label = np.argmax(predicted_probabilities, axis=1)
predicted_note = le.inverse_transform(predicted_label)

print(f"The predicted note is: {predicted_note[0]}")
# Out:
# The predicted note is: B

# %%
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt

# Load the audio file
audio_path = '/Users/elaineran/Desktop/summer-project/multiplethings.wav'
y, sr = librosa.load(audio_path)

# Harmonic Percussive Source Separation (HPSS)
y_harmonic, y_percussive = librosa.effects.hpss(y)

# Compute Chromagram
chromagram = librosa.feature.chroma_cqt(y=y_harmonic, sr=sr)

# Plot Chromagram
plt.figure(figsize=(15, 5))
librosa.display.specshow(chromagram, x_axis='time', y_axis='chroma', cmap='coolwarm')
plt.title('Chromagram')
plt.colorbar()
plt.tight_layout()
plt.show()

# Detect chords (using librosa's beat-synchronous chromagram)
tempo, beat_frames = librosa.beat.beat_track(y=y_percussive, sr=sr)
chroma_sync = librosa.util.sync(chromagram, beat_frames, aggregate=np.median)

# Estimate chords
chord_labels = librosa.sequence.viterbi(chroma_sync)

# Plot chord labels
plt.figure(figsize=(15, 5))
librosa.display.specshow(chroma_sync, x_axis='time', y_axis='chroma', cmap='coolwarm')
plt.plot(librosa.frames_to_time(beat_frames), chord_labels, color='white', linewidth=2)
plt.title('Chord Recognition')
plt.colorbar()
plt.tight_layout()
plt.show()

# Identify chord changes
chord_changes = np.diff(chord_labels) != 0
change_times = librosa.frames_to_time(np.where(chord_changes)[0])

print("Chord changes detected at times (seconds):", change_times)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-bdf06745ba7f> in <module>
#      27
#      28 # Estimate chords
# ---> 29 chord_labels = librosa.sequence.viterbi(chroma_sync)
#      30
#      31 # Plot chord labels
#
# TypeError: viterbi() missing 1 required positional argument: 'transition'

# %%
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import soundfile as sf

# Step 1: Load the audio file
audio_path = '/Users/elaineran/Downloads/archive2/piano_triads/A_maj_4_0.wav'
y, sr = librosa.load(audio_path)

# Step 2: Harmonic Percussive Source Separation (HPSS)
y_harmonic, y_percussive = librosa.effects.hpss(y)

# Step 3: Compute the Chromagram
chromagram = librosa.feature.chroma_cqt(y=y_harmonic, sr=sr)

# Plot Chromagram
plt.figure(figsize=(15, 5))
librosa.display.specshow(chromagram, x_axis='time', y_axis='chroma', cmap='coolwarm')
plt.title('Chromagram')
plt.colorbar()
plt.tight_layout()
plt.show()

# Step 4: Identify Peaks in the Chromagram
# Sum the chromagram across time to get the intensity of each pitch class
chroma_sum = np.sum(chromagram, axis=1)
# Identify peaks in the summed chromagram
peaks = np.argsort(chroma_sum)[-3:]  # Get indices of top 3 peaks

# Map chroma to note names
note_names = np.array(['C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#', 'A', 'A#', 'B'])
identified_notes = note_names[peaks]
print("Identified notes:", identified_notes)

# Step 5: Use the Chromagram to Create Masks and Isolate Notes Using STFT Frames
# Compute the STFT of the harmonic component
D_harmonic = librosa.stft(y_harmonic)
S_magnitude, S_phase = librosa.magphase(D_harmonic)

# Initialize an empty list to store the isolated notes
isolated_components = []

# Iterate over the identified peaks
for peak in peaks:
    # Create a mask for the identified note
    mask = chromagram[peak, :]
    mask = np.repeat(mask, S_magnitude.shape[1] // chromagram.shape[1])
    mask = mask[:S_magnitude.shape[1]]  # Ensure the mask length matches the number of STFT frames
    masked_S = S_magnitude * mask

    # Inverse transform to get the time-domain signal
    isolated_y = librosa.istft(masked_S * S_phase)
    isolated_components.append(isolated_y)

# Step 6: Save and/or visualize the isolated components (notes)
for i, component in enumerate(isolated_components):
    sf.write(f'isolated_note_{identified_notes[i]}.wav', component, sr)
    plt.figure(figsize=(10, 4))
    librosa.display.waveshow(component, sr=sr)
    plt.title(f'Isolated Note {identified_notes[i]}')
    plt.show()
# Out:
# Identified notes: ['A' 'E' 'C#']

# %%
import tensorflow as tf
from magenta.models.onsets_frames.transcription import model
from magenta.models.onsets_frames.transcription import infer_util
from magenta.music import audio_io
import librosa
import numpy as np

# Load the pre-trained model
checkpoint_path = 'path/to/onsets_frames_checkpoint'
transcription_model = model.OnsetsAndFrames()
transcription_model.restore_checkpoint(checkpoint_path)

# Load and preprocess the audio file
filename = 'your_audio_file.wav'
y, sr = librosa.load(filename, sr=16000)  # Model expects 16kHz sample rate

# Ensure the audio is mono
if y.ndim > 1:
    y = librosa.to_mono(y)

# Normalize the audio
y = y / np.max(np.abs(y))

# Use the model to transcribe the audio
frame_predictions, onset_predictions, _, _, _ = infer_util.run_on_audio(
    transcription_model, y, sr)

# Convert frame predictions to note events
notes = infer_util.predict_notes(frame_predictions, onset_predictions, sr)

# Convert note events to note names
def midi_to_note_name(midi_number):
    note_names = ['C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#', 'A', 'A#', 'B']
    octave = (midi_number // 12) - 1
    note = note_names[midi_number % 12]
    return f"{note}{octave}"

note_names = [midi_to_note_name(note[0]) for note in notes]
print("Detected notes:", note_names)
